# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal29july/BDA_assign__2/blob/main/BDA(assign_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#Description:**
# assignment1: cell number [128] to cell number [154]
#
# assignment2: cell number [155] to cell number [187]

# %% [markdown]
# #**ASSIGNMENT 1**

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread("/content/drive/MyDrive/WhatsApp Image 2021-02-26 at 8.38.41 PM.jpeg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=920x1258 at 0x7F2195A0E490>

# %%
#import Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Mounting Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Reading data
data=pd.read_csv("/content/drive/MyDrive/AK(Project)/Copy of Data.csv")

# %%
data

# %%
data.shape #number of rows and coloums
# Out:
# (25694, 34)

# %%
data["retweets"].min() #minimum value of retweets
# Out:
# 0

# %%
data["retweets"].max() #maximum value of retweets
# Out:
# 62666

# %%
data["retweets"].unique() #finding unique values in retweets coloumn
# Out:
# array([    0,     1,     2,    47,     6,     3,     5,     8,    23,
#           16,    12,    11,     7,    13,   276,    53,     4,  1665,
#          213,    36,    61,   284,   124,    99,    10,    42,   112,
#           30,   462,  6388,  1029,    19,    64,    84,   498,    15,
#           35,   847,     9,    14,    63,    83,    39,   175,    17,
#          187,    21,   106,    26,   586,    32,    62,   243,    41,
#           60,    43,   140,   130,    68,   211,   324,   761,    52,
#           29,    33,    69,   927,    22,    25,  2793,    31,   248,
#         8280,   249,    18,    89,   145,    49,   484,    24,   442,
#          138,    78,    67,    81,    20,   364,    71,   219,    73,
#         2872,  5598,    48,    45,   279,   128,   502,    28,   141,
#          121, 62666,    38,   104,    57,    44,   474,   137,   270,
#          508,   282,    97,    37,   169,    65,    34,   161,    75,
# ...

# %%
data["retweets"].value_counts() #counting frequency of retweets
# Out:
# 0      15827
# 1       4677
# 2       1683
# 3        776
# 4        498
#        ...
# 424        1
# 216        1
# 200        1
# 184        1
# 407        1
# Name: retweets, Length: 294, dtype: int64

# %%
Y_array = np.asarray(data[['retweets']]) #converting column of retweets into list/array

# %%
Y_array
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [6],
#        [4],
#        [0]])

# %%
#printing retweets column into array
y_arr_final=[]
for i in Y_array:
  i=i[0]
  y_arr_final.append(i)
y_arr_final.sort()
print(y_arr_final)

# %%
#dictionary which show "retweets" and "frequency" where key is retweets and value is frequency
d={}
for i in y_arr_final:
  if i not in d:
    d[i]=1
  else:
    d[i]=d[i]+1
print(d)
# Out:
# {0: 15827, 1: 4677, 2: 1683, 3: 776, 4: 498, 5: 286, 6: 218, 7: 158, 8: 119, 9: 100, 10: 103, 11: 57, 12: 62, 13: 49, 14: 52, 15: 37, 16: 40, 17: 48, 18: 27, 19: 38, 20: 23, 21: 19, 22: 23, 23: 26, 24: 16, 25: 18, 26: 18, 27: 13, 28: 16, 29: 18, 30: 19, 31: 16, 32: 20, 33: 13, 34: 10, 35: 15, 36: 12, 37: 10, 38: 14, 39: 7, 40: 4, 41: 5, 42: 7, 43: 7, 44: 7, 45: 5, 46: 7, 47: 9, 48: 4, 49: 12, 50: 1, 51: 3, 52: 6, 53: 6, 54: 3, 55: 3, 56: 4, 57: 8, 58: 6, 59: 4, 60: 4, 61: 11, 62: 9, 63: 5, 64: 7, 65: 5, 66: 4, 67: 3, 68: 4, 69: 4, 70: 2, 71: 2, 72: 5, 73: 2, 74: 4, 75: 4, 76: 4, 77: 4, 78: 2, 79: 2, 80: 2, 81: 5, 82: 3, 83: 3, 84: 4, 85: 5, 86: 3, 87: 3, 88: 4, 89: 4, 90: 2, 91: 1, 92: 1, 93: 1, 94: 2, 95: 5, 97: 2, 98: 4, 99: 2, 101: 2, 102: 2, 103: 1, 104: 1, 105: 3, 106: 3, 107: 1, 108: 1, 111: 1, 112: 2, 113: 3, 114: 1, 115: 3, 118: 1, 119: 2, 121: 1, 122: 2, 123: 2, 124: 2, 125: 2, 126: 1, 127: 1, 128: 2, 129: 3, 130: 3, 131: 1, 132: 1, 134: 1, 136: 2, 137: 2, 138: 2, 139: 1, 14
# ...

# %%
#frequency array:
fr_arr=[]
for i in d:
  fr_arr.append(d[i])
#print(fr_arr)

# %%
#sum of frequency array except, frequency of "0" and "1"
sum=0
for i in range(2,len(fr_arr)):
  sum=sum + fr_arr[i]
print(sum)
# Out:
# 5190

# %%
#sum of frequencies:
#print(d)
sum=0
for i in d:
  sum=sum+d[i]
sum_of_freq=sum
print(sum_of_freq)
# Out:
# 25694

# %%
#cummulative of frequencies
sum=0
cumm_freq=[]
for i in d:
  sum=sum+d[i]
  cumm_freq.append(sum)
print(cumm_freq)
# Out:
# [15827, 20504, 22187, 22963, 23461, 23747, 23965, 24123, 24242, 24342, 24445, 24502, 24564, 24613, 24665, 24702, 24742, 24790, 24817, 24855, 24878, 24897, 24920, 24946, 24962, 24980, 24998, 25011, 25027, 25045, 25064, 25080, 25100, 25113, 25123, 25138, 25150, 25160, 25174, 25181, 25185, 25190, 25197, 25204, 25211, 25216, 25223, 25232, 25236, 25248, 25249, 25252, 25258, 25264, 25267, 25270, 25274, 25282, 25288, 25292, 25296, 25307, 25316, 25321, 25328, 25333, 25337, 25340, 25344, 25348, 25350, 25352, 25357, 25359, 25363, 25367, 25371, 25375, 25377, 25379, 25381, 25386, 25389, 25392, 25396, 25401, 25404, 25407, 25411, 25415, 25417, 25418, 25419, 25420, 25422, 25427, 25429, 25433, 25435, 25437, 25439, 25440, 25441, 25444, 25447, 25448, 25449, 25450, 25452, 25455, 25456, 25459, 25460, 25462, 25463, 25465, 25467, 25469, 25471, 25472, 25473, 25475, 25478, 25481, 25482, 25483, 25484, 25486, 25488, 25490, 25491, 25492, 25495, 25497, 25498, 25500, 25501, 25504, 25505, 25507, 25509, 25511, 255
# ...

# %%
#cummulative dictionary:
j=0
for i in d:
  print("retweets:" ,i   ,  "frequency:", d[i]   ,"cummulative freq:" ,cumm_freq[j])
  j=j+1

# %% [markdown]
# **Finding quartiles based on formula shown below in program**

# %%
#first quartiles:
N1=sum_of_freq
q_1=1*(N1+1)/4
print(q_1)#6423.75 th item
# Out:
# 6423.75

# %%
#spliting  item
res1=[]
for i in cumm_freq:
  if (i>q_1):
    res1.append(i)

    
qq1=min(res1)
print(min(res1))
# Out:
# 15827

# %% [markdown]
# **retweets: 0 frequency: 15827 cummulative freq: 15827**

# %%
#third quantile:
N3=sum_of_freq
q_3=3*(N3+1)/4
print(q_3)#6423.75 th item
# Out:
# 19271.25

# %%
#spliting  item
res3=[]
for i in cumm_freq:
  if (i>q_3):
    res3.append(i)
    

qq3=min(res3)    
print(min(res3))
# Out:
# 20504

# %% [markdown]
# **retweets: 1 frequency: 4677 cummulative freq: 20504**

# %%
#here we tried to draw uniformly but we want exact high frequency of retweets
temp = data[(data['retweets'] <5)&(data['retweets'] >=0)]
print(len(temp)) 
temp.retweets.hist(bins=4)
# Out:
# 23461

# %%
#Bar graph of q1 ,q3 and remaining retweets ,which are divided on the basis of above used formulas
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
quartiles = ["q_1", "q_3","remaining_retweets"]
no_of_retweets = [15827, 4677,5190]
ax.bar(quartiles,no_of_retweets)
plt.show()

# %% [markdown]
# ********************************************************************************
#
# ********************************************************************************

# %% [markdown]
# #**Assignment 2**

# %%
img1=cv2.imread("/content/drive/MyDrive/WhatsApp Image 2021-04-04 at 6.37.49 PM.jpeg")
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=899x1280 at 0x7F21728FA590>

# %% [markdown]
# re-tweet column in the form of array:

# %%
#Re-tweet column
print(len(y_arr_final))
# Out:
# 25694

# %%
#mean of all data in retweet column
total=0
for i in y_arr_final:
  total=total+i
#print(total)
mean=total/len(y_arr_final)
print(mean)
# Out:
# 9.884953685685375

# %% [markdown]
# first part=15827+4677=20504 numbers of retweets

# %%
demo1=[]
for ele in range(0,20504):
  demo1.append(y_arr_final[ele])
#print(demo1)
print("max is :" ,max(demo1))
print("min is :" ,min(demo1))
# Out:
# max is : 1
# min is : 0

# %%
sum_1=0
for ele in range(0,20504):
  sum_1=sum_1+ y_arr_final[ele]
mean_of_sum_1=sum_1/20504
print("mean of part 1: ",mean_of_sum_1)

tempo1=0
var1=0
for ele in range(0,20504):
  var1=var1+(mean_of_sum_1 - y_arr_final[ele])**2
  tempo1=tempo1 + (mean_of_sum_1 - y_arr_final[ele])**3
  final_var1=var1/20503
  final_tempo1=tempo1/20503
print("valuue of T part 1: ",final_tempo1)
print("varience of  part 1: ",final_var1)
# Out:
# mean of part 1:  0.22810183378852908
# valuue of T part 1:  -0.09575164451059653
# varience of  part 1:  0.17607997480226403

# %% [markdown]
# Skewnewss of part 1 : T/(variance)**0.5

# %%
skewness_part1=final_tempo1/(final_var1)**0.5
print(skewness_part1)
# Out:
# -0.22818718874715213

# %% [markdown]
# *******************************************************************************
# *******************************************************************************

# %% [markdown]
# part2=20505 to 21000

# %%
demo2=[]
for ele in range(20505,21000):
  demo2.append(y_arr_final[ele])
#print(demo2)
print("max is :" ,max(demo2))
print("min is :" ,min(demo2))
# Out:
# max is : 2
# min is : 2

# %%
sum_2=0
for ele in range(20505,21000):
  sum_2=sum_2+ y_arr_final[ele]
mean_of_sum_2=sum_2/494
print("mean of part 2: ",mean_of_sum_2)

tempo2=0
var2=0
for ele in range(20505,21000):
  var2=var2+(mean_of_sum_2 - y_arr_final[ele])**2
  tempo2=tempo2 + (mean_of_sum_2 - y_arr_final[ele])**3
  final_var2=var2/494
  final_tempo2=tempo2/494
print("valuue of T for part 2: ",final_tempo2)
print("varience of  part 2: ",final_var2)
# Out:
# mean of part 2:  2.0040485829959516
# valuue of T for part 2:  6.649475500482593e-08
# varience of  part 2:  1.6424204486191364e-05

# %% [markdown]
# Skewnwss of part 2 : T/(variance)**0.5

# %%
skewness_part2=(final_tempo2)/(final_var2)**0.5
print(skewness_part2)
# Out:
# 1.640760599333444e-05

# %% [markdown]
# ********************************************************************************
#
# ********************************************************************************

# %% [markdown]
# part3=21000 to 22000

# %%
demo3=[]
for ele in range(21000,22000):
  demo3.append(y_arr_final[ele])
#print(demo3)
print("max is :" ,max(demo3))
print("min is :" ,min(demo3))
# Out:
# max is : 2
# min is : 2

# %%
sum_3=0
for ele in range(21000,22000):
  sum_3=sum_3+ y_arr_final[ele]
mean_of_sum_3=sum_3/999
print("mean of part 3: ",mean_of_sum_3)

tempo3=0
var3=0
for ele in range(21000,22000):
  var3=var3+(mean_of_sum_3 - y_arr_final[ele])**2
  tempo3=tempo3 + (mean_of_sum_3 - y_arr_final[ele])**3
  final_var3=var3/999
  final_tempo3=tempo3/999
print("valuue of T for part 3: ",final_tempo3)
print("varience of  part 3: ",final_var3)
# Out:
# mean of part 3:  2.002002002002002
# valuue of T for part 3:  8.032080160282568e-09
# varience of  part 3:  4.012024040060834e-06

# %% [markdown]
# Skewness of part 3: T/(variance)**0.5

# %%
skewness_part3=(final_tempo3)/(final_var3)**0.5
print(skewness_part3) #here we got slightly high skewness
# Out:
# 4.010017526286824e-06

# %% [markdown]
# ********************************************************************************
#
# ********************************************************************************

# %% [markdown]
# part3=22000 to 24000

# %%
demo4=[]
for ele in range(22000,24000):
  demo4.append(y_arr_final[ele])
#print(demo4)
print("max is :" ,max(demo4))
print("min is :" ,min(demo4))
# Out:
# max is : 7
# min is : 2

# %%
sum_4=0
for ele in range(22000,24000):
  sum_4=sum_4+ y_arr_final[ele]
mean_of_sum_4=sum_4/2000
print("mean of part 4: ",mean_of_sum_4)

tempo4=0
var4=0
for ele in range(22000,24000):
  var4=var4+(mean_of_sum_4 - y_arr_final[ele])**2
  tempo4=tempo4 + (mean_of_sum_4 - y_arr_final[ele])**3
  final_var4=var4/1999
  final_tempo4=tempo4/1999
print("valuue of T for part 4: ",final_tempo4)
print("varience of  part 4: ",final_var4)
# Out:
# mean of part 4:  3.8385
# valuue of T for part 4:  -1.06963349999996
# varience of  part 4:  1.4731543271635743

# %% [markdown]
# Skewness of part 4: T/(variance)**0.5

# %%
skewness_part4=(final_tempo4)/(final_var4)**0.5
print(skewness_part4)
# Out:
# -0.8812738292961938

# %% [markdown]
# ********************************************************************************
#
# ********************************************************************************

# %% [markdown]
# #mean representation of each part

# %%
w = 7
h = 5
d = 80
plt.figure(figsize=(w, h), dpi=d)
plt.axis([0, 5, 0, 5])
x = [1,2,3,4]
y = [mean_of_sum_1,mean_of_sum_2,mean_of_sum_3,mean_of_sum_4]
size = 1000

plt.scatter(x, y, s=size)
plt.savefig("out.png")

# %%
y = np.array([0.228, 2.004, 2.002, 3.88])
mylabels = ["mean of part1", "mean of part2", "mean of part3", "mean of part4"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# #skewness representation

# %%
w = 7
h = 5
d = 80
plt.figure(figsize=(w, h), dpi=d)
plt.axis([0, 4, 0, 5])
x = [1,2,3,4]
y = [skewness_part1,skewness_part2, skewness_part3,skewness_part4]
size = 8000

plt.scatter(x, y, s=size)
plt.savefig("out.png")

# %%
y = np.array([-0.22, 1.64, 4.012, -0.88])
mylabels = ["skewness part1", "skewness part2", "skewness part4", "skewness part 5"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()
